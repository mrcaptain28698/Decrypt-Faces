# %%
# !pip install kaggle

# %%
# !ls
# Out:
# sample_data

# %%
# !mkdir .kaggle

# %%
import json
token = {"username":"mrcaptain","key":"a3ca7a42b6288d324b8343e486778bd5"}
with open('/content/.kaggle/kaggle.json', 'w') as file:
  json.dump(token, file)

# %%
# %cd .kaggle
# !ls
# Out:
# /content/.kaggle
# kaggle.json

# %%
# %cd .kaggle
# !kaggle config set -n path -v{/content}
# Out:
# /content/.kaggle
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
import kaggle
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-2e5e3441a2d1> in <module>()
# ----> 1 import kaggle
#
# /usr/local/lib/python3.6/dist-packages/kaggle/__init__.py in <module>()
#      21
#      22 api = KaggleApi(ApiClient())
# ---> 23 api.authenticate()
#
# /usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py in authenticate(self)
#     164                 raise IOError('Could not find {}. Make sure it\'s located in'
#     165                               ' {}. Or use the environment method.'.format(
# --> 166                                   self.config_file, self.config_dir))
#     167
#     168         # Step 3: load into configuration!
#
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !cd drive sample_data
# !ls
# Out:
# /bin/bash: line 0: cd: too many arguments
# drive  sample_data

# %%
# !cd sample_data
# !ls
# Out:
# drive  sample_data

# %%
# !cd .kaggle
# !ls
# Out:
# /bin/bash: line 0: cd: .kaggle: No such file or directory
# drive  sample_data

# %%
mkdir .kaggle

# %%
# !ls
# Out:
# drive  sample_data

# %%
mkdir kaggle

# %%
# !ls
# Out:
# drive  kaggle  sample_data

# %%
# !cd ../../

# %%
# !ls
# Out:
# drive  kaggle  sample_data

# %%
# !cd ../../
# !ls
# Out:
# drive  kaggle  sample_data

# %%
import json
token = {"username":"mrcaptain","key":"a3ca7a42b6288d324b8343e486778bd5"}
with open('/root/.kaggle/kaggle.json', 'w') as file:
  json.dump(token, file)

# %%
# %cd ../
# Out:
# /content

# %%
# !ls
# Out:
# drive  kaggle  sample_data

# %%
# %cd ../../
# Out:
# /

# %%
# !ls
# Out:
# bin	 datalab  home	 lib64	opt   run   swift	       tmp    var
# boot	 dev	  lib	 media	proc  sbin  sys		       tools
# content  etc	  lib32  mnt	root  srv   tensorflow-1.15.2  usr

# %%
# %cd root/
# Out:
# /root

# %%
# !ls

# %%
# !mkdir .kaggle
# Out:
# mkdir: cannot create directory ‘.kaggle’: File exists

# %%
import json
token = {"username":"mrcaptain","key":"a3ca7a42b6288d324b8343e486778bd5"}
with open('/root/.kaggle/kaggle.json', 'w') as file:
  json.dump(token, file)

# %%
# !kaggle config set -n path -v{/content}
# Out:
# ...
# - path is now set to: {/content}

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                          title                                           size  lastUpdated          downloadCount
# -----------------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------
# babyoda/women-entrepreneurship-and-labor-force               Women Entrepreneurship and Labor Force           1KB  2020-11-21 08:38:51            410
# sakshigoyal7/credit-card-customers                           Credit Card customers                          379KB  2020-11-19 07:38:44            753
# imoore/2020-us-general-election-turnout-rates                2020 US General Election Turnout rates           4KB  2020-11-26 00:21:15            272
# alexgude/california-traffic-collision-data-from-switrs       California Traffic Collision Data from SWITRS    1GB  2020-11-22 16:51:55             80
# ...

# %%
# !kaggle datasets list -s celeba
# Out:
# ...
# ref                                                   title                                        size  lastUpdated          downloadCount
# ----------------------------------------------------  ------------------------------------------  -----  -------------------  -------------
# jessicali9530/celeba-dataset                          CelebFaces Attributes (CelebA) Dataset        1GB  2018-06-01 20:08:48          41084
# zuozhaorui/celeba                                     celeba                                        3GB  2018-11-03 05:29:21            335
# ruchi798/periocular-detection                         Periocular Recognition                       13MB  2020-08-09 00:45:00            104
# ashishjangra27/gender-recognition-200k-images-celeba  Gender Classification 200K Images | CelebA    1GB  2020-05-22 20:15:23            248
# ahmedshawaf/celeba                                    celeba                                        1GB  2020-04-07 21:56:35            133
# ...
